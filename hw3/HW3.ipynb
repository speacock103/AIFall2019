# %% [markdown]
# <a href="https://colab.research.google.com/github/speacock103/AIFall2019/blob/master/hw3/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 3, modifying pre-made netowork to identify tanks

# %% [markdown]
# It is of note that the majority of code was derived from UgurUysal86 github for image classification.
# link: https://github.com/UgurUysal86/MLS4MIL/blob/master/Image%20Classification/code/RuTanks_train.py

# %%
#mount google drive locally
from google.colab import drive
drive.mount('/content/drive')

# !unzip "/content/drive/My Drive/Colab Notebooks/RuTanks7000_v1.zip"
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Archive:  /content/drive/My Drive/Colab Notebooks/RuTanks7000_v1.zip
#    creating: RuTanks7000_v1/test/
#    creating: RuTanks7000_v1/test/Background/
#   inflating: RuTanks7000_v1/test/Background/Background_01.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_02.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_03.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_04.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_05.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_06.jpg
#   inflating: RuTanks7000_v1/test/Background/Background_07.jpg
#   inflating: RuTanks7000_v1/test/Background/Background_08.jpg
#   inflating: RuTanks7000_v1/test/Background/Background_09.jpg
#   inflating: RuTanks7000_v1/test/Background/Background_10.jpg
#   inflating: RuTanks7000_v1/test/Background/Background_11.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_12.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_13.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_14.JPG
#   inflating: RuTanks7000_v1/test/Background/Background_15.JPG
#    creating: RuTanks7000_v1/test/BMP2/
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_01.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_02.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_03.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_04.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_05.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_06.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_07.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_08.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_09.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_10.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_11.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_12.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_13.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_14.jpg
#   inflating: RuTanks7000_v1/test/BMP2/BMP2_15.jpg
#    creating: RuTanks7000_v1/test/Buk-M1-2/
#   inflating: RuTanks7000_v1/test/Buk-M1-2/Buk-M1-2_01.jpg
#   inflating: RuTanks7000_v1/test/Buk-M1-2/Buk-M1-2_02.jpg
#   inflating: RuTanks7000_v1/test/Buk-M1-2/Buk-M1-2_03.jpg
#   inflating: RuTanks7000_v1/test/Buk-M1-2/Buk-M1-2_04.jpg
jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_747.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_748.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_749.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_75.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_750.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_751.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_752.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_753.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_754.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_755.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_756.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_757.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_758.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_759.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_76.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_760.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_761.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_762.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_763.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_764.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_765.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_766.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_767.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_768.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_769.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_77.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_770.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_771.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_772.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_773.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_774.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_775.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_776.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_777.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_778.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_779.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_78.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_780.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_781.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_782.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_783.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_784.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_785.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_786.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_787.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_788.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_789.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_79.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_790.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_791.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_792.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_793.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_794.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_795.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_796.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_797.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_798.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_799.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_8.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_80.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_800.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_801.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_802.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_803.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_804.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_805.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_806.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_807.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_808.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_809.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_81.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_810.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_811.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_812.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_813.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_814.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_815.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_816.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_817.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_818.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_819.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_82.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_820.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_821.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_822.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_823.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_824.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_825.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_826.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_827.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_828.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_829.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_83.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_830.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_831.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_832.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_833.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_834.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_835.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_836.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_837.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_838.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_839.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_84.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_840.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_841.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_842.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_843.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_844.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_845.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_846.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_847.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_848.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_849.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_85.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_850.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_851.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_852.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_853.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_854.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_855.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_856.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_857.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_858.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_859.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_86.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_860.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_861.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_862.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_863.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_864.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_865.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_866.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_867.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_868.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_869.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_87.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_870.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_871.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_872.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_873.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_874.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_875.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_876.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_877.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_878.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_879.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_88.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_880.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_881.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_882.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_883.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_884.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_885.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_886.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_887.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_888.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_889.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_89.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_890.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_891.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_892.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_893.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_894.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_895.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_896.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_897.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_898.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_899.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_9.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_90.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_900.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_901.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_902.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_903.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_904.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_905.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_906.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_907.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_908.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_909.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_91.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_910.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_911.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_912.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_913.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_914.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_915.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_916.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_917.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_918.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_919.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_92.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_920.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_921.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_922.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_923.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_924.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_925.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_926.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_927.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_928.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_929.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_93.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_930.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_931.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_932.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_933.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_934.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_935.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_936.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_937.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_938.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_939.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_94.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_940.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_941.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_942.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_943.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_944.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_945.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_946.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_947.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_948.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_949.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_95.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_950.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_951.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_952.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_953.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_954.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_955.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_956.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_957.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_958.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_959.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_96.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_960.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_961.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_962.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_963.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_964.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_965.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_966.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_967.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_968.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_969.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_97.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_970.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_971.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_972.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_973.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_974.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_975.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_976.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_977.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_978.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_979.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_98.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_980.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_981.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_982.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_983.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_984.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_985.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_986.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_987.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_988.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_989.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_99.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_990.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_991.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_992.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_993.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_994.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_995.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_996.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_997.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_998.jpg
#   inflating: RuTanks7000_v1/train/ZSU23/ZSU23_999.jpg

# %%
#create needed directoires
# !mkdir -p /content/trained_models/trained_weights
# !mkdir -p /content/trained_models/RuTanks7000_v1
# !mkdir -p /content/logs

# %%
#imports
import os
from keras.applications import NASNetLarge
from keras import models, layers, optimizers, backend
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import matplotlib.pyplot as plt
import numpy as np
from timeit import default_timer as timer

#calls each level of network and times runtime
def main():
    start = timer()
    level1()  # Training the classifier only
    level2()  # Training the pretrained model + the trained classifier from level 1
    end = timer()
    print("Time elapsed in minutes: ", ((end - start)/60))

#image dimensions
img_height,img_width = 331, 331  # For NASNetLarge

#classes, here the civilian car class was removed
classnames = ["Background", "BMP2", "Buk-M1-2", "T14", "T90", "ZSU23"]
classes = len(classnames)

#path settings, for accessing and writing data
path = '/content/'
dataset_path = path+'RuTanks7000_v1/'
weights_path = path+'trained_models/trained_weights/weights_temp.h5'
model_path = path+'trained_models/RuTanks7000_v1_'
TensorBoardLogDir = path+'logs'

nbrTrainImages = 7000  # per class
nbrTestImages = 0  # Value gets accurate after counting (Total Number of test images)
for ImagesClass in os.listdir(dataset_path+'test'):
    nbrTestImages += len(os.listdir(dataset_path+'test/'+ImagesClass))

#unfreezing the base network up to a specific layer in Level2:
freezeUptoLayer = "normal_add_1_15"   # NASNetLarge

#hyperparameters
learning_rate = 0.0002  # Learning_rate in Level 2 = learning_rate/10
lr_decay = 0.0001
batch = 64
fcLayer1 = 32
dropout = 0.5

epochsL1 = 10
patiencel1 = 1
factorL1 = 0.5

epochsL2 = 10
patiencel2 = 1
factorL2 = 0.5

verbose_train = 1

# datagenerators https://keras.io/preprocessing/image/
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest',
    horizontal_flip=True)
train_generator = train_datagen.flow_from_directory(
    dataset_path+'train',
    target_size=(img_height, img_width),
    batch_size=batch,
    shuffle=True,
    classes=classnames,
    class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    dataset_path+'test',
    target_size=(img_height, img_width),
    batch_size=1,
    shuffle=True,
    classes=classnames,
    class_mode='categorical')

# function to plot results of model performance
def plot(h,t,e):
    history_dict = h[0]
    loss_values = history_dict['loss']
    validation_loss_values = history_dict['val_loss']
    acc_values = history_dict['acc']
    validation_acc_values = history_dict['val_acc']
    epochs_range = range(1, e + 1)

    # Plotting Training and Validation loss of the corresponding Model
    plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
    plt.plot(epochs_range, validation_loss_values, 'ro', label='Validation loss')
    plt.title('Training and validation loss of ' + t)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.yticks(np.arange(0, 3.1, step=0.2))
    plt.legend()
    plt.show()

    # Plotting Training and Validation accuracy of the corresponding Model
    plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
    plt.plot(epochs_range, validation_acc_values, 'ro', label='Validation accuracy')
    plt.title('Training and validation accuracy of ' + t)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.yticks(np.arange(0.3, 1.1, step=0.1))
    plt.legend()
    plt.show()


# LEVEL1 - Training of densely connected layers
def level1():
    # Building the model using the pretrained model
    conv_base1 = NASNetLarge(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
    print("\n### LEVEL1 ###\npretrained network:")
    conv_base1.summary()
    model = models.Sequential()
    model.add(conv_base1)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dense(fcLayer1, activation='relu'))
    model.add(layers.Dropout(dropout))
    model.add(layers.Dense(classes, activation='softmax'))

    # freezing the base network
    print("trainable layers bevor freezing:", int(len(model.trainable_weights)/2)) # weights = weights + bias = 2 pro layer
    conv_base1.trainable = False
    print("trainable layers after freezing:", int(len(model.trainable_weights)/2))
    print("\npretrained network + densely connected classifier")
    model.summary()

    # training the added layers only
    model.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(lr=learning_rate, decay=lr_decay), metrics=['acc'])

    callbacks_list_L1 = [ModelCheckpoint(filepath=weights_path, save_weights_only=True, monitor='val_acc', verbose=1, save_best_only=True),
                     ReduceLROnPlateau(monitor='val_acc', factor=factorL1, patience=patiencel1, verbose=1),
                     TensorBoard(log_dir=TensorBoardLogDir+'\\level1')]

    print("\n### Level1 Training ... ")
    # training the model
    history = model.fit_generator(
        train_generator,
        steps_per_epoch= (batch * 5),
        epochs=epochsL1,
        callbacks=callbacks_list_L1,
        validation_data=test_generator,
        validation_steps=nbrTestImages,
        verbose=verbose_train)

    history_val1 = [history.history]  # saving all results of the final test
    plot(history_val1, "LEVEL1:", epochsL1)
    print("\n### LEVEL1 Training finished successfully ###")

    print("\nLoading trained weights from " + weights_path + " ...")
    model.load_weights(weights_path)
    model.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(lr=learning_rate), metrics=['acc'])
    print("\n### Saving Level1 Model to ", model_path+'l1.h5', " ... ")
    model.save(model_path+'/l1.h5')


# LEVEL2 - Training pretrained network and trained densely connected layers
def level2():
    # Destroying the current TF graph - https://keras.io/backend/
    backend.clear_session()
    print("\n### LEVEL2 ###")
    conv_base2 = NASNetLarge(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))
    model2 = models.Sequential()
    model2.add(conv_base2)
    model2.add(layers.GlobalAveragePooling2D())
    model2.add(layers.Dense(fcLayer1, activation='relu'))
    model2.add(layers.Dropout(dropout))
    model2.add(layers.Dense(classes, activation='softmax'))

    print("\nLoading trained weights from " + weights_path + " ...")
    model2.load_weights(weights_path)

    # unfreezing the base network up to a specific layer:
    if freezeUptoLayer == "":
        conv_base2.trainable = True
        print ("\ntrainable layers: ",int(len(model2.trainable_weights) / 2))
    else:
        print("\ntrainable layers before unfreezing the base network up to " + freezeUptoLayer + ": ",int(len(model2.trainable_weights) / 2))  # weights = weights + bias = 2 pro layer
        conv_base2.trainable = True
        set_trainable = False
        for layer in conv_base2.layers:
            if layer.name == freezeUptoLayer: set_trainable = True
            if set_trainable: layer.trainable = True
            else: layer.trainable = False
        print("trainable layers after the base network unfreezed from layer " + freezeUptoLayer + ": ", int(len(model2.trainable_weights)/2))

    print("\nLEVEL2 Model after unfreezing the base network")
    model2.summary()
    model2.compile(loss='categorical_crossentropy', optimizer=optimizers.RMSprop(lr=learning_rate/10, decay=lr_decay), metrics=['acc'])
    print ("\n### Validating ... ")

    val_loss, val_acc = model2.evaluate_generator(test_generator, steps=nbrTestImages, verbose=0)
    print('Validation Results before training unfreeze layers and trained densely connected layers:\nValidation loss:',val_loss,",",'Validation accuracy:', val_acc, "\n")

    # Jointly training both the unfreeze layers and the added trained densely connected layers
    callbacks_list_L2 = [ModelCheckpoint(filepath=model_path+'l2.h5', save_weights_only=False, monitor='val_acc', verbose=1, save_best_only=True),
                   ReduceLROnPlateau(monitor='val_acc', factor=factorL2, patience=patiencel2, verbose=1),
                   TensorBoard(log_dir=TensorBoardLogDir+'\\level2')]

    print ("\n### Level2 Training ... ")
    history = model2.fit_generator(
        train_generator,
        steps_per_epoch= (batch * 5),
        epochs=epochsL2,
        callbacks=callbacks_list_L2,
        validation_data=test_generator,
        validation_steps=nbrTestImages,
        verbose=verbose_train)

    history_val2 = [history.history]  # saving all results of the final test
    plot(history_val2, "LEVEL2:", epochsL2)
    print("\n###LEVEL2 Training finished successfully ###")


main()
# Out:
# Found 42000 images belonging to 6 classes.
# Found 90 images belonging to 6 classes.
#
# ### LEVEL1 ###
# pretrained network:
# Model: "NASNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 331, 331, 3)  0
# __________________________________________________________________________________________________
# stem_conv1 (Conv2D)             (None, 165, 165, 96) 2592        input_2[0][0]
# __________________________________________________________________________________________________
# stem_bn1 (BatchNormalization)   (None, 165, 165, 96) 384         stem_conv1[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_1 (Conv2D (None, 165, 165, 42) 4032        activation_261[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_1 (BatchNor (None, 165, 165, 42) 168         reduction_conv_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 165, 165, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 169, 169, 42) 0           activation_262[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 171, 171, 96) 0           activation_264[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 83, 83, 42)   2814        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 83, 83, 42)   2814        activation_263[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   3822        activation_265[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 171, 171, 96) 0           activation_266[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_1 (Add)    (None, 83, 83, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   8736        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 169, 169, 96) 0           activation_268[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 83, 83, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 83, 83, 42)   6432        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 83, 83, 42)   2142        activation_270[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_1 (ZeroPad (None, 167, 167, 42) 0           reduction_bn_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   3822        activation_267[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 83, 83, 42)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_1 (MaxPool (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 83, 83, 42)   2814        activation_269[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 83, 83, 42)   2142        activation_271[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_stem_2 (Activatio (None, 165, 165, 96) 0           stem_bn1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_1 (Add)    (None, 83, 83, 42)   0           reduction_left2_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_1 (Average (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 83, 83, 42)   168         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_1 (Average (None, 83, 83, 42)   0           reduction_add_1_stem_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 83, 83, 42)   168         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_1 (MaxPoo (None, 83, 83, 42)   0           reduction_pad_1_stem_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 166, 166, 96) 0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_1 (Add)     (None, 83, 83, 42)   0           reduction_left3_stem_1[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 83, 83, 42)   0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_left4_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_1 (Add)     (None, 83, 83, 42)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_1[0][0]
# __________________________________________________________________________________________________
# cropping2d_5 (Cropping2D)       (None, 165, 165, 96) 0           zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_1 (Concat (None, 83, 83, 168)  0           reduction_add_2_stem_1[0][0]
#                                                                  reduction_add3_stem_1[0][0]
#                                                                  add_5[0][0]
#                                                                  reduction_add4_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_stem_2 (Avera (None, 83, 83, 96)   0           adjust_relu_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_stem_2 (Avera (None, 83, 83, 96)   0           cropping2d_5[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 83, 83, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_stem_2 (Conv2D)   (None, 83, 83, 42)   4032        adjust_avg_pool_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_stem_2 (Conv2D)   (None, 83, 83, 42)   4032        adjust_avg_pool_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_conv_1_stem_2 (Conv2D (None, 83, 83, 84)   14112       activation_272[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 83, 83, 84)   0           adjust_conv_1_stem_2[0][0]
#                                                                  adjust_conv_2_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_bn_1_stem_2 (BatchNor (None, 83, 83, 84)   336         reduction_conv_1_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_bn_stem_2 (BatchNormaliz (None, 83, 83, 84)   336         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 83, 83, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 87, 87, 84)   0           activation_273[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 89, 89, 84)   0           activation_275[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 42, 42, 84)   9156        separable_conv_1_pad_reduction_le
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_1_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right1
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 42, 42, 84)   9156        activation_274[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   11172       activation_276[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_2_reduction_left1_
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right1
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 89, 89, 84)   0           activation_277[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 83, 83, 84)   0           adjust_bn_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add_1_stem_2 (Add)    (None, 42, 42, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   11172       separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_pad_reduction_ (None, 87, 87, 84)   0           activation_279[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 42, 42, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_1_reduction_righ (None, 42, 42, 84)   9156        separable_conv_1_pad_reduction_ri
# __________________________________________________________________________________________________
# separable_conv_1_reduction_left (None, 42, 42, 84)   7812        activation_281[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_1_reduction_right3
# __________________________________________________________________________________________________
# separable_conv_1_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_1_reduction_left4_
# __________________________________________________________________________________________________
# reduction_pad_1_stem_2 (ZeroPad (None, 85, 85, 84)   0           reduction_bn_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   11172       activation_278[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_rig
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 42, 42, 84)   0           separable_conv_1_bn_reduction_lef
# __________________________________________________________________________________________________
# reduction_left2_stem_2 (MaxPool (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right2
# __________________________________________________________________________________________________
# separable_conv_2_reduction_righ (None, 42, 42, 84)   9156        activation_280[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_reduction_left (None, 42, 42, 84)   7812        activation_282[0][0]
# __________________________________________________________________________________________________
# adjust_relu_1_0 (Activation)    (None, 83, 83, 168)  0           reduction_concat_stem_1[0][0]
# __________________________________________________________________________________________________
# reduction_add_2_stem_2 (Add)    (None, 42, 42, 84)   0           reduction_left2_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# reduction_left3_stem_2 (Average (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_r (None, 42, 42, 84)   336         separable_conv_2_reduction_right3
# __________________________________________________________________________________________________
# reduction_left4_stem_2 (Average (None, 42, 42, 84)   0           reduction_add_1_stem_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_reduction_l (None, 42, 42, 84)   336         separable_conv_2_reduction_left4_
# __________________________________________________________________________________________________
# reduction_right5_stem_2 (MaxPoo (None, 42, 42, 84)   0           reduction_pad_1_stem_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 84, 84, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# reduction_add3_stem_2 (Add)     (None, 42, 42, 84)   0           reduction_left3_stem_2[0][0]
#                                                                  separable_conv_2_bn_reduction_rig
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 42, 42, 84)   0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_left4_stem_2[0][0]
# __________________________________________________________________________________________________
# reduction_add4_stem_2 (Add)     (None, 42, 42, 84)   0           separable_conv_2_bn_reduction_lef
#                                                                  reduction_right5_stem_2[0][0]
# __________________________________________________________________________________________________
# cropping2d_6 (Cropping2D)       (None, 83, 83, 168)  0           zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# reduction_concat_stem_2 (Concat (None, 42, 42, 336)  0           reduction_add_2_stem_2[0][0]
#                                                                  reduction_add3_stem_2[0][0]
#                                                                  add_6[0][0]
#                                                                  reduction_add4_stem_2[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_1_0 (AveragePoo (None, 42, 42, 168)  0           adjust_relu_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_avg_pool_2_0 (AveragePoo (None, 42, 42, 168)  0           cropping2d_6[0][0]
# __________________________________________________________________________________________________
# adjust_conv_1_0 (Conv2D)        (None, 42, 42, 84)   14112       adjust_avg_pool_1_0[0][0]
# __________________________________________________________________________________________________
# adjust_conv_2_0 (Conv2D)        (None, 42, 42, 84)   14112       adjust_avg_pool_2_0[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 42, 42, 336)  0           reduction_concat_stem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 42, 42, 168)  0           adjust_conv_1_0[0][0]
#                                                                  adjust_conv_2_0[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_0 (Conv2D)        (None, 42, 42, 168)  56448       activation_283[0][0]
# __________________________________________________________________________________________________
# adjust_bn_0 (BatchNormalization (None, 42, 42, 168)  672         concatenate_6[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_0 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_0[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 42, 42, 168)  0           normal_bn_1_0[0][0]
# __________________________________________________________________________________________________
bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left1_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right1_1[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left2_1[0
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 42, 42, 168)  672         separable_conv_2_normal_right2_1[
# __________________________________________________________________________________________________
# normal_left3_1 (AveragePooling2 (None, 42, 42, 168)  0           normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_left4_1 (AveragePooling2 (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_right4_1 (AveragePooling (None, 42, 42, 168)  0           adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 42, 42, 168)  672         separable_conv_2_normal_left5_1[0
# __________________________________________________________________________________________________
# normal_add_1_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_1 (Add)            (None, 42, 42, 168)  0           normal_left3_1[0][0]
#                                                                  adjust_bn_1[0][0]
# __________________________________________________________________________________________________
# normal_add_4_1 (Add)            (None, 42, 42, 168)  0           normal_left4_1[0][0]
#                                                                  normal_right4_1[0][0]
# __________________________________________________________________________________________________
# normal_add_5_1 (Add)            (None, 42, 42, 168)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_1[0][0]
# __________________________________________________________________________________________________
# normal_concat_1 (Concatenate)   (None, 42, 42, 1008) 0           adjust_bn_1[0][0]
#                                                                  normal_add_1_1[0][0]
#                                                                  normal_add_2_1[0][0]
#                                                                  normal_add_3_1[0][0]
#                                                                  normal_add_4_1[0][0]
#                                                                  normal_add_5_1[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 42, 42, 1008) 0           normal_concat_0[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 42, 42, 1008) 0           normal_concat_1[0][0]
# __________________________________________________________________________________________________
# adjust_conv_projection_2 (Conv2 (None, 42, 42, 168)  169344      activation_306[0][0]
# __________________________________________________________________________________________________
# normal_conv_1_2 (Conv2D)        (None, 42, 42, 168)  169344      activation_307[0][0]
# __________________________________________________________________________________________________
# adjust_bn_2 (BatchNormalization (None, 42, 42, 168)  672         adjust_conv_projection_2[0][0]
# __________________________________________________________________________________________________
# normal_bn_1_2 (BatchNormalizati (None, 42, 42, 168)  672         normal_conv_1_2[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 42, 42, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 42, 42, 168)  0           adjust_bn_2[0][0]
# __________________________________________________________________________________________________
# activation_316 (Activation)     (None, 42, 42, 168)  0           normal_bn_1_2[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left1_2 (None, 42, 42, 168)  32424       activation_308[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right1_ (None, 42, 42, 168)  29736       activation_310[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left2_2 (None, 42, 42, 168)  32424       activation_312[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_right2_ (None, 42, 42, 168)  29736       activation_314[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_2 (None, 42, 42, 168)  29736       activation_316[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 42, 42, 168)  672         separable_conv_1_normal_left1_2[0
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# separable_conv_1_normal_left5_1 (None, 11, 11, 672)  457632      activation_518[0][0]
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_1_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_1_normal_right2_18
# __________________________________________________________________________________________________
# separable_conv_1_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_1_normal_left5_18[
# __________________________________________________________________________________________________
# activation_511 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left1_
# __________________________________________________________________________________________________
# activation_513 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right1
# __________________________________________________________________________________________________
# activation_515 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left2_
# __________________________________________________________________________________________________
# activation_517 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_right2
# __________________________________________________________________________________________________
# activation_519 (Activation)     (None, 11, 11, 672)  0           separable_conv_1_bn_normal_left5_
# __________________________________________________________________________________________________
# separable_conv_2_normal_left1_1 (None, 11, 11, 672)  468384      activation_511[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right1_ (None, 11, 11, 672)  457632      activation_513[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left2_1 (None, 11, 11, 672)  468384      activation_515[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_right2_ (None, 11, 11, 672)  457632      activation_517[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_normal_left5_1 (None, 11, 11, 672)  457632      activation_519[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left1_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right1_18
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left2_18[
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_righ (None, 11, 11, 672)  2688        separable_conv_2_normal_right2_18
# __________________________________________________________________________________________________
# normal_left3_18 (AveragePooling (None, 11, 11, 672)  0           normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_left4_18 (AveragePooling (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_right4_18 (AveragePoolin (None, 11, 11, 672)  0           adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# separable_conv_2_bn_normal_left (None, 11, 11, 672)  2688        separable_conv_2_normal_left5_18[
# __________________________________________________________________________________________________
# normal_add_1_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left1_
#                                                                  separable_conv_2_bn_normal_right1
# __________________________________________________________________________________________________
# normal_add_2_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left2_
#                                                                  separable_conv_2_bn_normal_right2
# __________________________________________________________________________________________________
# normal_add_3_18 (Add)           (None, 11, 11, 672)  0           normal_left3_18[0][0]
#                                                                  adjust_bn_18[0][0]
# __________________________________________________________________________________________________
# normal_add_4_18 (Add)           (None, 11, 11, 672)  0           normal_left4_18[0][0]
#                                                                  normal_right4_18[0][0]
# __________________________________________________________________________________________________
# normal_add_5_18 (Add)           (None, 11, 11, 672)  0           separable_conv_2_bn_normal_left5_
#                                                                  normal_bn_1_18[0][0]
# __________________________________________________________________________________________________
# normal_concat_18 (Concatenate)  (None, 11, 11, 4032) 0           adjust_bn_18[0][0]
#                                                                  normal_add_1_18[0][0]
#                                                                  normal_add_2_18[0][0]
#                                                                  normal_add_3_18[0][0]
#                                                                  normal_add_4_18[0][0]
#                                                                  normal_add_5_18[0][0]
# __________________________________________________________________________________________________
# activation_520 (Activation)     (None, 11, 11, 4032) 0           normal_concat_18[0][0]
# ==================================================================================================
# Total params: 84,916,818
# Trainable params: 84,720,150
# Non-trainable params: 196,668
# __________________________________________________________________________________________________
# trainable layers bevor freezing: 510
# trainable layers after freezing: 2
#
# pretrained network + densely connected classifier
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# NASNet (Model)               (None, 11, 11, 4032)      84916818
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 4032)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                129056
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 85,046,072
# Trainable params: 129,254
# Non-trainable params: 84,916,818
# _________________________________________________________________
#
# ### Level1 Training ...
# Epoch 1/10
# 320/320 [==============================] - 543s 2s/step - loss: 1.0915 - acc: 0.6023 - val_loss: 1.2331 - val_acc: 0.5444
#
# Epoch 00001: val_acc improved from -inf to 0.54444, saving model to /content/trained_models/trained_weights/weights_temp.h5
# Epoch 2/10
# 320/320 [==============================] - 517s 2s/step - loss: 0.6980 - acc: 0.7655 - val_loss: 1.1033 - val_acc: 0.6111
#
# Epoch 00002: val_acc improved from 0.54444 to 0.61111, saving model to /content/trained_models/trained_weights/weights_temp.h5
# Epoch 3/10
# 320/320 [==============================] - 521s 2s/step - loss: 0.5741 - acc: 0.8097 - val_loss: 1.0569 - val_acc: 0.5889
#
# Epoch 00003: val_acc did not improve from 0.61111
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 4/10
# 320/320 [==============================] - 515s 2s/step - loss: 0.5193 - acc: 0.8284 - val_loss: 1.0502 - val_acc: 0.6111
#
# Epoch 00004: val_acc did not improve from 0.61111
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 5/10
# 320/320 [==============================] - 523s 2s/step - loss: 0.4898 - acc: 0.8419 - val_loss: 1.0554 - val_acc: 0.6111
#
# Epoch 00005: val_acc did not improve from 0.61111
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 6/10
# 320/320 [==============================] - 522s 2s/step - loss: 0.4888 - acc: 0.8403 - val_loss: 1.0284 - val_acc: 0.6222
#
# Epoch 00006: val_acc improved from 0.61111 to 0.62222, saving model to /content/trained_models/trained_weights/weights_temp.h5
# Epoch 7/10
# 320/320 [==============================] - 526s 2s/step - loss: 0.4890 - acc: 0.8402 - val_loss: 1.0305 - val_acc: 0.6111
#
# Epoch 00007: val_acc did not improve from 0.62222
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 8/10
# 320/320 [==============================] - 524s 2s/step - loss: 0.4708 - acc: 0.8479 - val_loss: 1.0196 - val_acc: 0.6111
#
# Epoch 00008: val_acc did not improve from 0.62222
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 9/10
# 320/320 [==============================] - 523s 2s/step - loss: 0.4750 - acc: 0.8433 - val_loss: 1.0174 - val_acc: 0.6222
#
# Epoch 00009: val_acc did not improve from 0.62222
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 10/10
# 320/320 [==============================] - 522s 2s/step - loss: 0.4762 - acc: 0.8436 - val_loss: 1.0182 - val_acc: 0.6222
#
# Epoch 00010: val_acc did not improve from 0.62222
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# ### LEVEL1 Training finished successfully ###
#
# Loading trained weights from /content/trained_models/trained_weights/weights_temp.h5 ...
#
# ### Saving Level1 Model to  /content/trained_models/RuTanks7000_v1_l1.h5  ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
#
# ### LEVEL2 ###
#
# Loading trained weights from /content/trained_models/trained_weights/weights_temp.h5 ...
#
# trainable layers before unfreezing the base network up to normal_add_1_15:  510
# trainable layers after the base network unfreezed from layer normal_add_1_15:  71
#
# LEVEL2 Model after unfreezing the base network
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# NASNet (Model)               (None, 11, 11, 4032)      84916818
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 4032)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                129056
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 198
# =================================================================
# Total params: 85,046,072
# Trainable params: 30,292,646
# Non-trainable params: 54,753,426
# _________________________________________________________________
#
# ### Validating ...
# Validation Results before training unfreeze layers and trained densely connected layers:
# Validation loss: 1.0283897509358617 , Validation accuracy: 0.6222222222222222
#
#
# ### Level2 Training ...
# Epoch 1/10
# 320/320 [==============================] - 642s 2s/step - loss: 0.3061 - acc: 0.9005 - val_loss: 0.6155 - val_acc: 0.8444
#
# Epoch 00001: val_acc improved from -inf to 0.84444, saving model to /content/trained_models/RuTanks7000_v1_l2.h5
# Epoch 2/10
# 320/320 [==============================] - 615s 2s/step - loss: 0.1654 - acc: 0.9456 - val_loss: 0.6117 - val_acc: 0.8222
#
# Epoch 00002: val_acc did not improve from 0.84444
#
# Epoch 00002: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# Epoch 3/10
# 320/320 [==============================] - 617s 2s/step - loss: 0.1205 - acc: 0.9607 - val_loss: 0.6475 - val_acc: 0.8444
#
# Epoch 00003: val_acc did not improve from 0.84444
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# Epoch 4/10
# 320/320 [==============================] - 619s 2s/step - loss: 0.1063 - acc: 0.9649 - val_loss: 0.6340 - val_acc: 0.8111
#
# Epoch 00004: val_acc did not improve from 0.84444
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# Epoch 5/10
# 320/320 [==============================] - 617s 2s/step - loss: 0.1010 - acc: 0.9662 - val_loss: 0.6438 - val_acc: 0.8222
#
# Epoch 00005: val_acc did not improve from 0.84444
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# Epoch 6/10
# 320/320 [==============================] - 614s 2s/step - loss: 0.0986 - acc: 0.9681 - val_loss: 0.6526 - val_acc: 0.8444
#
# Epoch 00006: val_acc did not improve from 0.84444
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# Epoch 7/10
# 320/320 [==============================] - 616s 2s/step - loss: 0.1008 - acc: 0.9660 - val_loss: 0.6542 - val_acc: 0.8333
#
# Epoch 00007: val_acc did not improve from 0.84444
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# Epoch 8/10
# 320/320 [==============================] - 613s 2s/step - loss: 0.0985 - acc: 0.9671 - val_loss: 0.6485 - val_acc: 0.8222
#
# Epoch 00008: val_acc did not improve from 0.84444
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# Epoch 9/10
# 320/320 [==============================] - 616s 2s/step - loss: 0.0926 - acc: 0.9678 - val_loss: 0.6466 - val_acc: 0.8222
#
# Epoch 00009: val_acc did not improve from 0.84444
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
# Epoch 10/10
# 320/320 [==============================] - 616s 2s/step - loss: 0.0955 - acc: 0.9667 - val_loss: 0.6473 - val_acc: 0.8222
#
# Epoch 00010: val_acc did not improve from 0.84444
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-08.
# ###LEVEL2 Training finished successfully ###
# Time elapsed in minutes:  194.9577125636
